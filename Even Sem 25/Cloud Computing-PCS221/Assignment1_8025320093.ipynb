# %% [markdown]
# # Lab Assignment 1 – PCS221 Cloud Computing
# **Name:** Simran
# **Roll No:** 8025320093
# **Group:** CS-02
#
# ---
# ## Introduction to Google Colab Cloud

# %%
print("Welcome to Google Colab Cloud!")
print("This notebook runs entirely in the cloud using Google's infrastructure.")
print("No installation needed — Python, libraries, and GPU/TPU are available on demand.")
# Out:
# Welcome to Google Colab Cloud!
# This notebook runs entirely in the cloud using Google's infrastructure.
# No installation needed — Python, libraries, and GPU/TPU are available on demand.

# %% [markdown]
# ## Interacting with the Colab Environment

# %%
import sys
import platform

print(f"Python Version: {sys.version}")
print(f"Platform: {platform.system()} {platform.release()}")
print(f"Python executable: {sys.executable}")

import os
print(f"\nCurrent Working Directory: {os.getcwd()}")
print(f"Files in current directory: {os.listdir('.')}")
# Out:
# Python Version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform: Linux 6.6.113+
# Python executable: /usr/bin/python3
#
# Current Working Directory: /content
# Files in current directory: ['.config', 'sample_data']

# %%
try:
    import subprocess
    result = subprocess.run(['nvidia-smi'], capture_output=True, text=True)
    print(result.stdout if result.returncode == 0 else "No GPU detected (running on CPU).")
except FileNotFoundError:
    print("nvidia-smi not found. Running on CPU / local environment.")
# Out:
# nvidia-smi not found. Running on CPU / local environment.

# %% [markdown]
# ## Using Google Colab Computational Resources

# %%
import psutil
import os

cpu_count = psutil.cpu_count(logical=True)
cpu_freq  = psutil.cpu_freq()
print(f"Logical CPUs : {cpu_count}")
if cpu_freq:
    print(f"CPU Frequency: {cpu_freq.current:.0f} MHz")

ram = psutil.virtual_memory()
print(f"\nTotal RAM   : {ram.total / (1024**3):.2f} GB")
print(f"Available RAM: {ram.available / (1024**3):.2f} GB")
print(f"Used RAM     : {ram.used / (1024**3):.2f} GB")
print(f"RAM Usage    : {ram.percent}%")

# Disk info
disk = psutil.disk_usage('/')
print(f"\nTotal Disk  : {disk.total / (1024**3):.2f} GB")
print(f"Free Disk   : {disk.free / (1024**3):.2f} GB")
print(f"Disk Usage  : {disk.percent}%")
# Out:
# Logical CPUs : 2
# CPU Frequency: 2200 MHz
#
# Total RAM   : 12.67 GB
# Available RAM: 11.82 GB
# Used RAM     : 0.58 GB
# RAM Usage    : 6.7%
#
# Total Disk  : 107.72 GB
# Free Disk   : 87.09 GB
# Disk Usage  : 19.1%

# %% [markdown]
# ## Python Environment in Google Colab

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("NumPy  version:", np.__version__)
print("Pandas version:", pd.__version__)

arr = np.array([10, 20, 30, 40, 50])
print("\nDemo Array:", arr)
print("Mean  :", np.mean(arr))
print("Std   :", np.std(arr))
print("Sum   :", np.sum(arr))
# Out:
# NumPy  version: 2.0.2
# Pandas version: 2.2.2
#
# Demo Array: [10 20 30 40 50]
# Mean  : 30.0
# Std   : 14.142135623730951
# Sum   : 150

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 25, 15, 40, 30]

plt.figure(figsize=(8, 4))
plt.plot(x, y, marker='o', color='royalblue', linewidth=2)
plt.title('Google Colab – Sample Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('lab1_plot.png', dpi=100)
plt.show()
print("Plot displayed successfully in Colab environment!")
# Out:
# Plot displayed successfully in Colab environment!
